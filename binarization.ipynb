# %% [markdown]
# <a href="https://colab.research.google.com/github/harsha0062/ml_learning/blob/main/binarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import KBinsDiscretizer
from sklearn.compose import ColumnTransformer

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ml -working/train.csv",usecols=['Age','Fare','SibSp','Parch','Survived'])

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (714, 5)

# %%
df.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare
# 0         0  22.0      1      0   7.2500
# 1         1  38.0      1      0  71.2833
# 2         1  26.0      0      0   7.9250
# 3         1  35.0      1      0  53.1000
# 4         0  35.0      0      0   8.0500

# %%
df['family']=df['SibSp']+df['Parch']

# %%
df.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare  family
# 0         0  22.0      1      0   7.2500       1
# 1         1  38.0      1      0  71.2833       1
# 2         1  26.0      0      0   7.9250       0
# 3         1  35.0      1      0  53.1000       1
# 4         0  35.0      0      0   8.0500       0

# %%
df.drop(columns=['SibSp','Parch'],inplace=True)

# %%
df.head()
# Out:
#    Survived   Age     Fare  family
# 0         0  22.0   7.2500       1
# 1         1  38.0  71.2833       1
# 2         1  26.0   7.9250       0
# 3         1  35.0  53.1000       1
# 4         0  35.0   8.0500       0

# %%
x=df.drop(columns=['Survived'])
y=df['Survived']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.head(2)
# Out:
#       Age     Fare  family
# 328  31.0  20.5250       2
# 73   26.0  14.4542       1

# %%
# without binarization
clf=DecisionTreeClassifier()
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)

accuracy_score(y_test,y_pred)
# Out:
# 0.6293706293706294

# %%
c=(np.mean(cross_val_score(DecisionTreeClassifier(),x,y,cv=10,scoring='accuracy')))
float(c)
# Out:
# 0.6541471048513301

# %%
# applying Binarization
from sklearn.preprocessing import Binarizer

# %%
trf=ColumnTransformer([
    ('bin',Binarizer(copy=False),['family'])
],remainder='passthrough')

# %%
x_train_trf=trf.fit_transform(x_train)
x_test_trf=trf.transform(x_test)

# %%
pd.DataFrame(x_train_trf,columns=['family','Age','Fare'])
# Out:
#      family   Age      Fare
# 0       1.0  31.0   20.5250
# 1       1.0  26.0   14.4542
# 2       1.0  30.0   16.1000
# 3       0.0  33.0    7.7750
# 4       0.0  25.0   13.0000
# ..      ...   ...       ...
# 566     1.0  46.0   61.1750
# 567     0.0  25.0   13.0000
# 568     0.0  41.0  134.5000
# 569     1.0  33.0   20.5250
# 570     0.0  33.0    7.8958
#
# [571 rows x 3 columns]

# %%
clf=DecisionTreeClassifier()
clf.fit(x_train_trf,y_train)
y_pred2=clf.predict(x_test_trf)

accuracy_score(y_test,y_pred2)
# Out:
# 0.6153846153846154

# %%
x_trf=trf.fit_transform(x)
c=np.mean(cross_val_score(DecisionTreeClassifier(),x,y,cv=10,scoring='accuracy'))
float(c)
# Out:
# 0.6471048513302036
