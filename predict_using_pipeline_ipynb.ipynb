# %% [markdown]
# <a href="https://colab.research.google.com/github/harsha0062/ml_learning/blob/main/predict_using_pipeline_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import numpy as np

# %%
pipe=pickle.load(open('/content/drive/MyDrive/Colab Notebooks/ml -working/colab/pipeline/pipe.pkl','rb'))

# %%
# assume user input
test_input2=np.array([2,'male',31.0,0,0,10.5,'S'],dtype=object).reshape(1,7)

# %%
import pandas as pd

test_df = pd.DataFrame(
    test_input2,
    columns=pipe.feature_names_in_
)

pipe.predict(test_df)
# Out:
# array([0])
