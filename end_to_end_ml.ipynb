# %% [markdown]
# <a href="https://colab.research.google.com/github/harsha0062/ml_learning/blob/main/end_to_end_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
cf=pd.read_csv('/content/placement.csv')

# %%
cf.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
cf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
cf.describe()
# Out:
#        Unnamed: 0        cgpa          iq   placement
# count  100.000000  100.000000  100.000000  100.000000
# mean    49.500000    5.991000  123.580000    0.500000
# std     29.011492    1.143634   39.944198    0.502519
# min      0.000000    3.300000   37.000000    0.000000
# 25%     24.750000    5.075000  101.500000    0.000000
# 50%     49.500000    6.000000  127.500000    0.500000
# 75%     74.250000    6.900000  149.000000    1.000000
# max     99.000000    8.500000  233.000000    1.000000

# %%
cf.shape
# Out:
# (100, 4)

# %%
cf.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
cf=cf.iloc[:,1:]

# %%
cf.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(cf['cgpa'],cf['iq'],c=cf['placement'])

# %%
x=cf.iloc[:,0:2]
y=cf.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 49   5.4  135.0
# 14   6.1  103.0
# 57   6.5  130.0
# 17   3.3  183.0
# 54   6.4  141.0
# ..   ...    ...
# 9    5.1   66.0
# 19   5.2  132.0
# 58   8.0   79.0
# 23   4.7   87.0
# 31   3.9  109.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 48   6.6  138.0
# 90   7.3   86.0
# 62   6.0  102.0
# 85   5.8  166.0
# 93   6.8  112.0
# 45   6.0   66.0
# 60   6.9  139.0
# 86   5.1  128.0
# 63   6.3  128.0
# 71   6.1  132.0

# %%
y_train
# Out:
# 49    0
# 14    0
# 57    1
# 17    0
# 54    1
#      ..
# 9     0
# 19    0
# 58    1
# 23    0
# 31    0
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 48    1
# 90    1
# 62    0
# 85    1
# 93    1
# 45    1
# 60    1
# 86    0
# 63    1
# 71    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-4.73518324e-01,  2.68939632e-01],
#        [ 1.20737740e-01, -5.14221278e-01],
#        [ 4.60312634e-01,  1.46570740e-01],
#        [-2.25628652e+00,  1.44368100e+00],
#        [ 3.75418911e-01,  4.15782302e-01],
#        [-1.66203045e+00, -5.87642613e-01],
#        [-1.66203045e+00, -1.19948707e+00],
#        [-5.58412048e-01, -7.36932661e-02],
#        [-6.43305771e-01, -8.32380397e-01],
#        [-9.82880666e-01,  9.54205427e-01],
#        [ 1.13946242e+00, -1.96062158e-01],
#        [ 1.13946242e+00, -1.81133153e+00],
#        [ 4.60312634e-01, -8.32380397e-01],
#        [-2.08649907e+00,  2.66736992e+00],
#        [ 8.84781252e-01,  1.24789077e+00],
#        [-2.18837154e-01,  4.64729859e-01],
#        [ 8.84781252e-01,  1.83526145e+00],
#        [-1.06777439e+00, -1.76238398e+00],
#        [ 7.14993805e-01, -2.47457093e-02],
#        [ 1.20737740e-01, -1.44422486e+00],
#        [ 6.30100081e-01,  7.33941422e-01],
#        [ 8.84781252e-01, -1.46869864e+00],
# ...

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.54520636,  0.34236097],
#        [ 1.13946242, -0.93027551],
#        [ 0.03584402, -0.53869506],
#        [-0.13394343,  1.02762676],
#        [ 0.7149938 , -0.29395727],
#        [ 0.03584402, -1.41975108],
#        [ 0.79988753,  0.36683475],
#        [-0.72819949,  0.09762318],
#        [ 0.29052519,  0.09762318],
#        [ 0.12073774,  0.1955183 ]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
# model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 48    1
# 90    1
# 62    0
# 85    1
# 93    1
# 45    1
# 60    1
# 86    0
# 63    1
# 71    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
