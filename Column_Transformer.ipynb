# %% [markdown]
# <a href="https://colab.research.google.com/github/harsha0062/ml_learning/blob/main/Column_Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ml -working/covid_toy.csv')

# %%
df.sample(5)
# Out:
#     age  gender  fever   cough       city has_covid
# 21   73    Male   98.0    Mild  Bangalore       Yes
# 29   34  Female    NaN  Strong     Mumbai       Yes
# 85   16  Female  103.0    Mild  Bangalore       Yes
# 54   60  Female   99.0    Mild     Mumbai       Yes
# 25   23    Male    NaN    Mild     Mumbai        No

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop(columns=['has_covid']),df['has_covid'],test_size=0.2)

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
X_train.sample(5)
# Out:
#     age  gender  fever   cough       city
# 63   10    Male  100.0    Mild  Bangalore
# 11   65  Female   98.0    Mild     Mumbai
# 17   40  Female   98.0  Strong      Delhi
# 87   47    Male  101.0  Strong  Bangalore
# 72   83  Female  101.0    Mild    Kolkata

# %%
from sklearn.impute import SimpleImputer
si=SimpleImputer()
X_train_fever=si.fit_transform(X_train[['fever']])
X_test_fever=si.fit_transform(X_test[['fever']])
X_train_fever
# Out:
# array([[104.        ],
#        [ 98.        ],
#        [ 99.        ],
#        [ 98.        ],
#        [104.        ],
#        [103.        ],
#        [ 99.        ],
#        [ 98.        ],
#        [101.        ],
#        [ 99.        ],
#        [104.        ],
#        [ 98.        ],
#        [101.        ],
#        [104.        ],
#        [103.        ],
#        [100.97183099],
#        [ 98.        ],
#        [100.        ],
#        [102.        ],
#        [101.        ],
#        [100.97183099],
#        [101.        ],
#        [100.97183099],
#        [103.        ],
#        [100.97183099],
#        [101.        ],
#        [ 99.        ],
#        [100.97183099],
#        [100.        ],
#        [104.        ],
#        [ 98.        ],
#        [100.        ],
#        [100.        ],
#        [104.        ],
#        [103.        ],
#        [101.        ],
#        [103.        ],
#        [ 98.        ],
#        [ 99.        ],
#        [104.        ],
# ...

# %%
# OrdinalEncoder -> cough
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder(categories=[['Mild','Strong']])
X_train_cough=oe.fit_transform(X_train[['cough']])
X_test_cough=oe.fit_transform(X_test[['cough']])
X_train_cough.shape
# Out:
# (80, 1)

# %%
#  OneHotEncoder
from sklearn.preprocessing import OneHotEncoder
# Create encoder (NEW PARAMETER NAME)
ohe = OneHotEncoder(
    drop='first',
    sparse_output=False,
    handle_unknown='ignore'
)
# FIT + TRANSFORM on TRAIN data
X_train_gender_city = ohe.fit_transform(X_train[['gender','city']])
# ONLY TRANSFORM on TEST data
X_test_gender_city = ohe.transform(X_test[['gender','city']])
print(X_train_gender_city.shape)
print(X_test_gender_city.shape)
# Out:
# (80, 4)
# (20, 4)

# %%
X_train_age=X_train.drop(columns=['gender','fever','cough','city']).values
X_test_age=X_test.drop(columns=['gender','fever','cough','city']).values
X_train_age.shape
# Out:
# (80, 1)

# %%
x_train_transformed=np.concatenate((X_train_age,X_train_fever,X_train_gender_city,X_train_cough),axis=1)
# also the test data
x_test_transformed=np.concatenate((X_test_age,X_test_fever,X_test_gender_city,X_test_cough),axis=1)
x_train_transformed.shape
# Out:
# (80, 7)

# %%
from sklearn.compose import ColumnTransformer

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

transformer = ColumnTransformer(
    transformers=[
        ('tnf1', SimpleImputer(), ['fever']),
        ('tnf2', OrdinalEncoder(categories=[['Mild', 'Strong']]), ['cough']),
        ('tnf3', OneHotEncoder(sparse_output=False, drop='first'), ['gender', 'city'])
    ],
    remainder='passthrough'
)

# %%
transformer.fit_transform(X_train).shape
# Out:
# (80, 7)

# %%
transformer.transform(X_test).shape
# Out:
# (20, 7)
