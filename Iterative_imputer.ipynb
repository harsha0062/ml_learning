# %% [markdown]
# <a href="https://colab.research.google.com/github/harsha0062/ml_learning/blob/main/Iterative_imputer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df=np.round(
    pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ml -working/colab/Handling missing value/Iterative_imputer/50_Startups.csv")
    [['R&D Spend','Administration','Marketing Spend','Profit']]/10000
)

np.random.seed(9)
df=df.sample(5)
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit
# 21        8.0            15.0             30.0    11.0
# 37        4.0             5.0             20.0     9.0
# 2        15.0            10.0             41.0    19.0
# 14       12.0            16.0             26.0    13.0
# 44        2.0            15.0              3.0     7.0

# %%
df=df.iloc[:,0:-1]
df
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0            15.0             30.0
# 37        4.0             5.0             20.0
# 2        15.0            10.0             41.0
# 14       12.0            16.0             26.0
# 44        2.0            15.0              3.0

# %%
df = df.copy()

df.iloc[1,0] = np.nan
df.iloc[3,1] = np.nan
df.iloc[-1,-1] = np.nan

df.head()
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0            15.0             30.0
# 37        NaN             5.0             20.0
# 2        15.0            10.0             41.0
# 14       12.0             NaN             26.0
# 44        2.0            15.0              NaN

# %%
# step 1 - Impute all missing values with mean of respective col
df0=pd.DataFrame()

df0['R&D Spend']=df['R&D Spend'].fillna(df['R&D Spend'].mean())
df0['Administration']=df['Administration'].fillna(df['Administration'].mean())
df0['Marketing Spend']=df['Marketing Spend'].fillna(df['Marketing Spend'].mean())

df0
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37       9.25            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.25            26.00
# 44       2.00           15.00            29.25

# %%
# removw the col1 imputed value
df1=df0.copy()
df1.iloc[1,0]=np.nan
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0           15.00            30.00
# 37        NaN            5.00            20.00
# 2        15.0           10.00            41.00
# 14       12.0           11.25            26.00
# 44        2.0           15.00            29.25

# %%
# use first 3 rows to build a model and use the last of prediction
x=df1.iloc[[0,2,3,4],1:3]
x
# Out:
#     Administration  Marketing Spend
# 21           15.00            30.00
# 2            10.00            41.00
# 14           11.25            26.00
# 44           15.00            29.25

# %%
y=df1.iloc[[0,2,3,4],0]
y
# Out:
# 21     8.0
# 2     15.0
# 14    12.0
# 44     2.0
# Name: R&D Spend, dtype: float64

# %%
lr=LinearRegression()
lr.fit(x,y)

sample = pd.DataFrame(
    df1.iloc[1,1:].values.reshape(1,2),
    columns=x.columns
)

lr.predict(sample)
# Out:
# array([23.14158651])

# %%
df1.iloc[1,0]=23.14
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      23.14            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.25            26.00
# 44       2.00           15.00            29.25

# %%
# remove the col2 imputed value
df1.iloc[3,1]=np.nan
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00            15.0            30.00
# 37      23.14             5.0            20.00
# 2       15.00            10.0            41.00
# 14      12.00             NaN            26.00
# 44       2.00            15.0            29.25

# %%
# Use last 3 rows to build a model and use the first for prediction
x=df1.iloc[[0,1,2,4],[0,2]]
x
# Out:
#     R&D Spend  Marketing Spend
# 21       8.00            30.00
# 37      23.14            20.00
# 2       15.00            41.00
# 44       2.00            29.25

# %%
y=df1.iloc[[0,1,2,4],1]
y
# Out:
# 21    15.0
# 37     5.0
# 2     10.0
# 44    15.0
# Name: Administration, dtype: float64

# %%
lr=LinearRegression()
lr.fit(x,y)

sample = pd.DataFrame(
    df1.iloc[3,[0,2]].values.reshape(1,2),
    columns=x.columns
)

lr.predict(sample)
# Out:
# array([11.06331285])

# %%
df1.iloc[3,1]=11.06

# %%
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      23.14            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.06            26.00
# 44       2.00           15.00            29.25

# %%
# remove the col3 imputed value
df1.iloc[4,-1]=np.nan
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00             30.0
# 37      23.14            5.00             20.0
# 2       15.00           10.00             41.0
# 14      12.00           11.06             26.0
# 44       2.00           15.00              NaN

# %%
# use last 3 rows to build a model and use the first for prediction
x=df1.iloc[0:4,0:2]
x
# Out:
#     R&D Spend  Administration
# 21       8.00           15.00
# 37      23.14            5.00
# 2       15.00           10.00
# 14      12.00           11.06

# %%
y=df1.iloc[0:4,-1]
y
# Out:
# 21    30.0
# 37    20.0
# 2     41.0
# 14    26.0
# Name: Marketing Spend, dtype: float64

# %%
lr=LinearRegression()
lr.fit(x,y)

sample=pd.DataFrame(
    df1.iloc[4,0:2].values.reshape(1,2),
    columns=x.columns
)

lr.predict(sample)
# Out:
# array([31.56351448])

# %%
df1.iloc[4,-1]=31.56

# %%
# after 1st Iteration
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      23.14            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.06            26.00
# 44       2.00           15.00            31.56

# %%
# subtract 0th iteration from 1st iteration
df1-df0
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       0.00            0.00             0.00
# 37      13.89            0.00             0.00
# 2        0.00            0.00             0.00
# 14       0.00           -0.19             0.00
# 44       0.00            0.00             2.31

# %%
df2=df1.copy()
df2.iloc[1,0]=np.nan
df2
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0           15.00            30.00
# 37        NaN            5.00            20.00
# 2        15.0           10.00            41.00
# 14       12.0           11.06            26.00
# 44        2.0           15.00            31.56

# %%
x=df2.iloc[[0,2,3,4],1:3]
y=df2.iloc[[0,2,3,4],0]

lr=LinearRegression()
lr.fit(x,y)
sample=pd.DataFrame(
    df2.iloc[1,1:].values.reshape(1,2),
    columns=x.columns
)
lr.predict(sample)
# Out:
# array([23.78627207])

# %%
df2.iloc[1,0]=23.78

# %%
df2.iloc[3,1]=np.nan

x=df2.iloc[[0,1,2,4],[0,2]]
y=df2.iloc[[0,1,2,4],1]

lr=LinearRegression()
lr.fit(x,y)
sample=pd.DataFrame(
    df2.iloc[3,[0,2]].values.reshape(1,2),
    columns=x.columns
    )
lr.predict(sample)
# Out:
# array([11.22020174])

# %%
df2.iloc[3,1]=11.09

# %%
df.iloc[4,-1]=np.nan

x=df2.iloc[0:4,0:2]
y=df2.iloc[0:4,-1]

lr=LinearRegression()
lr.fit(x,y)
sample=pd.DataFrame(
    df2.iloc[4,0:2].values.reshape(1,2),
    columns=x.columns
    )
lr.predict(sample)
# Out:
# array([36.84808423])

# %%
df2.iloc[4,-1]=31.76

# %%
df2
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      23.78            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.09            26.00
# 44       2.00           15.00            31.76

# %%
df2-df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       0.00            0.00              0.0
# 37       0.64            0.00              0.0
# 2        0.00            0.00              0.0
# 14       0.00            0.03              0.0
# 44       0.00            0.00              0.2

# %%
df3=df2.copy()
df3.iloc[1,0]=np.nan
df3
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0           15.00            30.00
# 37        NaN            5.00            20.00
# 2        15.0           10.00            41.00
# 14       12.0           11.09            26.00
# 44        2.0           15.00            31.76

# %%
x=df3.iloc[[0,2,3,4],1:3]
y=df3.iloc[[0,2,3,4],0]

lr=LinearRegression()
lr.fit(x,y)

sample=pd.DataFrame(
    df3.iloc[1,1:].values.reshape(1,2),
    columns=x.columns
)

lr.predict(sample)
# Out:
# array([24.04994256])

# %%
df3.iloc[1,0]=24.04

# %%
df3.iloc[3,1]=np.nan
x=df3.iloc[[0,1,2,4],[0,2]]
y=df3.iloc[[0,1,2,4],1]

lr=LinearRegression()
lr.fit(x,y)

sample=pd.DataFrame(
    df3.iloc[3,[0,2]].values.reshape(1,2),
    columns=x.columns
)

lr.predict(sample)
# Out:
# array([11.27596253])

# %%
df3.iloc[3,1]=11.37

# %%
df3.iloc[4,-1]=np.nan

x=df3.iloc[0:4,0:2]
y=df3.iloc[0:4,-1]

lr=LinearRegression()
lr.fit(x,y)

sample=pd.DataFrame(
    df3.iloc[4,0:2].values.reshape(1,2),
    columns=x.columns
)

lr.predict(sample)
# Out:
# array([43.94493685])

# %%
df3.iloc[4,-1]=43.94

# %%
df2.iloc[3,1]=11.22

# %%
df3
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      24.04            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.37            26.00
# 44       2.00           15.00            43.94

# %%
df3-df2
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       0.00            0.00             0.00
# 37       0.26            0.00             0.00
# 2        0.00            0.00             0.00
# 14       0.00            0.15             0.00
# 44       0.00            0.00            12.18
