# %% [markdown]
# <a href="https://colab.research.google.com/github/harsha0062/ml_learning/blob/main/Regression_metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ml -working/colab/Regression Metrics/placement_regression_metrics.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('package')
# Out:
# Text(0, 0.5, 'package')

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,1]

# %%
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel('cgpa')
plt.ylabel('package')
# Out:
# Text(0, 0.5, 'package')

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred=lr.predict(x_test)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print("MAE:", mean_absolute_error(y_test,y_pred))
# Out:
# MAE: 0.2884710931878175

# %%
print("MSE:", mean_squared_error(y_test,y_pred))
# Out:
# MSE: 0.12129235313495527

# %%
print("MSE:", np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# MSE: 0.34827051717731616

# %%
print("R2 score:", r2_score(y_test,y_pred))
# Out:
# R2 score: 0.780730147510384

# %%
# adjusted r2 score
x_test.shape
# Out:
# (40, 1)

# %%
1-((1-r2_score(y_test,y_pred))*(40-1)/(40-1-1))
# Out:
# 0.7749598882343415

# %%
new_df1=df.copy()
new_df1['random_feature']=np.random.random(200)

new_df1=new_df1[['cgpa','random_feature','package']]
new_df1.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.124950     3.26
# 1  5.12        0.646576     1.98
# 2  7.82        0.254011     3.25
# 3  7.42        0.973589     3.67
# 4  6.94        0.095847     3.57

# %%
plt.scatter(new_df1['cgpa'],new_df1['package'])
plt.xlabel('cgpa')
plt.ylabel('package')
#
# Out:
# Text(0, 0.5, 'package')

# %%
x=new_df1.iloc[:,0:2]
y=new_df1.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
#

# %%
print("R2 Score:", r2_score(y_test,y_pred))
r2=r2_score(y_test,y_pred)
# Out:
# R2 Score: 0.7751039298126384

# %%
1-((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.7629473854781865

# %%
new_df2=df.copy()
new_df2['iq']=new_df2['package']+(np.random.randint(-12,12,200)/100)
new_df2=new_df2[['cgpa','iq','package']]

# %%
new_df2.sample(5)
# Out:
#      cgpa    iq  package
# 156  7.38  3.04     3.13
# 119  7.39  2.66     2.65
# 150  6.30  2.80     2.73
# 113  6.94  2.29     2.37
# 77   8.99  4.50     4.60

# %%
plt.scatter(new_df2['cgpa'],new_df2['package'])
plt.xlabel('iq')
plt.ylabel('package(in lpa)')
# Out:
# Text(0, 0.5, 'package(in lpa)')

# %%
np.random.randint(-100,100)
# Out:
# 78

# %%
x=new_df2.iloc[:,0:2]
y=new_df2.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
print("R2 Score:", r2_score(y_test,y_pred))
r2=r2_score(y_test,y_pred)
# Out:
# R2 Score: 0.9928898446276984

# %%
1-((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.9925055119048712
